# %%
# - comments - comments are not part of our program/code,they are only for labelling
#Run/execute a cell - Ctrl + enter,Shift + enter,Alt + enter

# %%
#[1] - here 1 means the order of execution
#[2] - here 2 means the order of execution

# %%
#.ipynb - .interactive python notebook
#.py - .python

# %%
#PYTHON BASICS

# %%
#VARIABLES - A NAMED MEMORY LOCATION
a = 100

# %%
a
# Out:
# 100

# %%
print(a)
# Out:
# 100

# %%
#Now let us check the datatype of a
type(a) #type(a) is integer
# Out:
# int

# %%
a = 51
a
# Out:
# 51

# %%
print(a)
# Out:
# 51

# %%
a = 54.8

# %%
a
# Out:
# 54.8

# %%
type(a)
# Out:
# float

# %%
a = 25

# %%
b = 36.9

# %%
c = True

# %%
d = 'Hello World'

# %%
#Now I want to print the values , which are stores in these variables
print(a)
print(b)
print(c)
print(d)
# Out:
# 25
# 36.9
# True
# Hello World

# %%
print(a,b,c,d)
# Out:
# 25 36.9 True Hello World

# %%
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'str'>

# %%
m = print(a,b,c,d)
m
# Out:
# 25 36.9 True Hello World

# %%
a = 25
b = 10

# %%
#Add
c = a+b
c
# Out:
# 35

# %%
#Subtraction
s = a-b
s
# Out:
# 15

# %%
#Multiplication
m = a*b
m
# Out:
# 250

# %%
#Division
d = a/b #Quotient in decimal point(Float)
d
# Out:
# 2.5

# %%
#Floor Division
e = a//b #Quotient in whole number
e
# Out:
# 2

# %%
f = a%b #Remainder
f
# Out:
# 5

# %%
#Builtin Functions - print(),input(),len(),max(),min()
#Functions are of 2 types - Builtin functions and User defined functions

# %%
print('Hello World')
# Out:
# Hello World

# %%
print("HELLO WORLD")
#In Python single or doubles quotes are both strings
# Out:
# HELLO WORLD

# %%
#input() - input() functions takes the user defined input
#The input captured using the input function is always in string format

# %%
a = input('Enter your Name')
a
# Out:
# Enter your NameAmeen
# 'Ameen'

# %%
type(a)
# Out:
# str

# %%
#Take 2 numbers as input using the input() and calculate their sum using python.
a = input('Enter the first number')
b = input('Enter the second number')
c = a + b
c
#1525 here is the output of strings being concatenated.
# Out:
# Enter the first number15
# Enter the second number25
# '1525'

# %%
#Typecasting
a = int(input('Enter the first number'))
b = int(input('Enter the second number'))
c = a + b
c
# Out:
# Enter the first number15
# Enter the second number25
# 40

# %%
a = input('Enter the first number')
b = input('Enter the second number')
c = int(a) + int(b)
c
# Out:
# Enter the first number25
# Enter the second number15
# 40

# %%
#Write a program to find the square of a number
a = int(input('enter a number'))
square = a**2
print(f'Square of {a} is',square)
# Out:
# enter a number8
# Square of 8 is 64

# %%
a = int(input('enter a number'))
square = a*a
print(f'Square of {a} is',square)
# Out:
# enter a number6
# Square of 6 is 36

# %%
a = int(input('enter a number'))
square = pow(a,2)
print(f'Square of {a} is',square)
# Out:
# enter a number4
# Square of 4 is 16

# %%
#STRINGS
s = 'Welcome to Incredible India'
s
# Out:
# 'Welcome to Incredible India'

# %%
type(s)
# Out:
# str

# %%
#Now I want to access the the 1st element from the string s
s[0]
#Indexing in Python always starts from 0 and ends at -1.
# Out:
# 'W'

# %%
s[11] #to access I from the word Incredible
# Out:
# 'I'

# %%
s[24]#to access the 'd' from the word india
# Out:
# 'd'

# %%
#Using the negative indexing , I want to access the letter 'd' from the word india
s[-3]
# Out:
# 'd'

# %%
s
# Out:
# 'Welcome to Incredible India'

# %%
#Now I want to access the word Incredible
#We have to perform Slicing
#var[inclusive index:exclusive index]
s[11:21]
# Out:
# 'Incredible'

# %%
#Now I want to access the word India
s[22:27]
# Out:
# 'India'

# %%
s[22:]
# Out:
# 'India'

# %%
s[-5:]
# Out:
# 'India'

# %%
s[22:-1]
# Out:
# 'Indi'

# %%
#CONDITIONAL STATEMENTS
#IF and ELSE
#Write a program to check if the given number is odd or even
a = 10
if(a%2 == 0):
  print('No is Even')
if(a%2 == 1):
  print('No if odd')
# Out:
# No is Even

# %%
a = 15
if(a%2 == 0):
  print('Number is Even')
else:
  print('Number is Odd')
# Out:
# Number is Odd

# %%
a = input('Enter the weather condition:')
if(a == 'summer'):
  print('It is summer season')
elif(a == 'winter'):
  print('It is winter season')
elif(a == 'monsoon'):
  print('It is rainy season')
else:
  print('Invalid Input')
# Out:
# Enter the weather condition:summer
# It is summer season

# %%
if(fbkjfnkjngf)
{
    
}
